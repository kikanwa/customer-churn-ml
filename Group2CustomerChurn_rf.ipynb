# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
from scipy import stats
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
train = pd.read_csv('Group2trainingdata_2.csv')

# %%
#Preparing the data
train.head()
# Out:
#   Customer ID  Gender  Age Married  Number of Dependents  Number of Referrals  \
# 0  0002-ORFBO  Female   37     Yes                     0                    2
# 1  0003-MKNFE    Male   46      No                     0                    0
# 2  0004-TLHLJ    Male   50      No                     0                    0
# 3  0011-IGKFF    Male   78     Yes                     0                    1
# 4  0013-EXCHZ  Female   75     Yes                     0                    3
#
#    Tenure in Months    Offer  Avg Monthly Long Distance Charges  \
# 0                 9      NaN                              42.39
# 1                 9      NaN                              10.69
# 2                 4  Offer E                              33.65
# 3                13  Offer D                              27.82
# 4                 3      NaN                               7.38
#
#          Contract  Monthly Charge
# 0        One Year            65.6
# 1  Month-to-Month            -4.0
# ...

# %%
train = train.dropna(subset=['Avg Monthly Long Distance Charges'])

# %%
train.head()
# Out:
#   Customer ID  Gender  Age Married  Number of Dependents  Number of Referrals  \
# 0  0002-ORFBO  Female   37     Yes                     0                    2
# 1  0003-MKNFE    Male   46      No                     0                    0
# 2  0004-TLHLJ    Male   50      No                     0                    0
# 3  0011-IGKFF    Male   78     Yes                     0                    1
# 4  0013-EXCHZ  Female   75     Yes                     0                    3
#
#    Tenure in Months    Offer  Avg Monthly Long Distance Charges  \
# 0                 9      NaN                              42.39
# 1                 9      NaN                              10.69
# 2                 4  Offer E                              33.65
# 3                13  Offer D                              27.82
# 4                 3      NaN                               7.38
#
#          Contract  Monthly Charge
# 0        One Year            65.6
# 1  Month-to-Month            -4.0
# ...

# %%
train.isnull().sum()
# Out:
# Customer ID                             0
# Gender                                  0
# Age                                     0
# Married                                 0
# Number of Dependents                    0
# Number of Referrals                     0
# Tenure in Months                        0
# Offer                                3494
# Avg Monthly Long Distance Charges       0
# Contract                                0
# Monthly Charge                          0
# dtype: int64

# %%
train['Offer'] = train['Offer'].fillna('None')


print(train['Offer'].value_counts())
# Out:
# Offer
# None       3494
# Offer B     747
# Offer E     717
# Offer D     557
# Offer A     474
# Offer C     372
# Name: count, dtype: int64

# %%
train
# Out:
#      Customer ID  Gender  Age Married  Number of Dependents  \
# 0     0002-ORFBO  Female   37     Yes                     0
# 1     0003-MKNFE    Male   46      No                     0
# 2     0004-TLHLJ    Male   50      No                     0
# 3     0011-IGKFF    Male   78     Yes                     0
# 4     0013-EXCHZ  Female   75     Yes                     0
# ...          ...     ...  ...     ...                   ...
# 6356  9986-BONCE  Female   36      No                     0
# 6357  9987-LUTYD  Female   20      No                     0
# 6358  9992-RRAMN    Male   40     Yes                     0
# 6359  9992-UJOEL    Male   22      No                     0
# 6360  9993-LHIEB    Male   21     Yes                     0
#
#       Number of Referrals  Tenure in Months    Offer  \
# 0                       2                 9     None
# 1                       0                 9     None
# 2                       0                 4  Offer E
# ...

# %%
Y= train['Customer Status']
x= train.drop(['Customer Status'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Customer Status'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 Y= train['Customer Status']
# ...

# %%
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 x
#
# NameError: name 'x' is not defined

# %%
Y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 Y
#
# NameError: name 'Y' is not defined

# %%
x.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 x.isnull().sum()
#
# NameError: name 'x' is not defined

# %%
Y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 Y
#
# NameError: name 'Y' is not defined

# %%
x_train, x_test, Y_train, Y_test = train_test_split(x, Y, stratify=Y, test_size = 0.25, random_state = 42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 x_train, x_test, Y_train, Y_test = train_test_split(x, Y, stratify=Y, test_size = 0.25, random_state = 42)
#
# NameError: name 'x' is not defined

# %%
# Print the shapes of the resulting arrays
print("Shape of x_train:", x_train.shape)
print("Shape of x_test:", x_test.shape)
print("Shape of Y_train:", Y_train.shape)
print("Shape of Y_test:", Y_test.shape)

# Print some sample values
print("\nSample values of x_train:")
print(x_train.head())  # Assuming x_train is a pandas DataFrame, adjust if it's a NumPy array

print("\nSample values of Y_train:")
print(Y_train.head())  # Assuming Y_train is a pandas Series, adjust if it's a NumPy array
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 2
#       1 # Print the shapes of the resulting arrays
# ----> 2 print("Shape of x_train:", x_train.shape)
#       3 print("Shape of x_test:", x_test.shape)
#       4 print("Shape of Y_train:", Y_train.shape)
#
# NameError: name 'x_train' is not defined

# %%
training_data = pd.concat([x_train, Y_train], axis=1)
training_data.to_csv("Group2_training_data.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 training_data = pd.concat([x_train, Y_train], axis=1)
#       2 training_data.to_csv("Group2_training_data.csv", index=False)
#
# NameError: name 'x_train' is not defined

# %%
testing_data = pd.concat([x_test, Y_test], axis=1)
testing_data.to_csv("Group2_testing_data.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 testing_data = pd.concat([x_test, Y_test], axis=1)
#       2 testing_data.to_csv("Group2_testing_data.csv", index=False)
#
# NameError: name 'x_test' is not defined

# %%
train1 = pd.read_csv('Group2_training_data.csv')

# %%
train1.head()
# Out:
#   Customer ID  Gender  Age Married  Number of Dependents  Number of Referrals  \
# 0  1135-HIORI  Female   48     Yes                     3                    3
# 1  5847-MXBEO    Male   42      No                     0                    0
# 2  2931-XIQBR  Female   41     Yes                     3                    7
# 3  4468-YDOVK    Male   57      No                     2                    0
# 4  8441-SHIPE  Female   53      No                     0                    0
#
#    Tenure in Months    Offer  Avg Monthly Long Distance Charges  \
# 0                64  Offer B                              39.37
# 1                22  Offer D                              10.36
# 2                50      NaN                              47.48
# 3                 5      NaN                              13.54
# 4                67      NaN                              16.72
#
#          Contract  Monthly Charge Customer Status
# 0        One Year          111.45          Stayed
# ...

# %%
Y= train1['Customer Status']
x= train1.drop(['Customer Status'], axis=1)

# %%
x
# Out:
#      Customer ID  Gender  Age Married  Number of Dependents  \
# 0     1135-HIORI  Female   48     Yes                     3
# 1     5847-MXBEO    Male   42      No                     0
# 2     2931-XIQBR  Female   41     Yes                     3
# 3     4468-YDOVK    Male   57      No                     2
# 4     8441-SHIPE  Female   53      No                     0
# ...          ...     ...  ...     ...                   ...
# 4765  4090-KPJIP  Female   42      No                     0
# 4766  2171-UDMFD    Male   22     Yes                     3
# 4767  6047-YHPVI    Male   56      No                     3
# 4768  1666-JXLKU  Female   64      No                     0
# 4769  9269-CQOOL    Male   58      No                     0
#
#       Number of Referrals  Tenure in Months    Offer  \
# 0                       3                64  Offer B
# 1                       0                22  Offer D
# 2                       7                50      NaN
# ...

# %%
x.isnull().sum()
# Out:
# Customer ID                             0
# Gender                                  0
# Age                                     0
# Married                                 0
# Number of Dependents                    0
# Number of Referrals                     0
# Tenure in Months                        0
# Offer                                2611
# Avg Monthly Long Distance Charges       0
# Contract                                0
# Monthly Charge                          0
# dtype: int64

# %%
import pandas as pd

# Assuming df is your DataFrame
# Replace NaN with 'None' in the 'Offer' column
x['Offer'] = x['Offer'].fillna('None')

# Verify the changes
print(x['Offer'].value_counts())
# Out:
# Offer
# None       2611
# Offer E     551
# Offer B     547
# Offer D     416
# Offer A     371
# Offer C     274
# Name: count, dtype: int64

# %%
x.isnull().sum()
# Out:
# Customer ID                          0
# Gender                               0
# Age                                  0
# Married                              0
# Number of Dependents                 0
# Number of Referrals                  0
# Tenure in Months                     0
# Offer                                0
# Avg Monthly Long Distance Charges    0
# Contract                             0
# Monthly Charge                       0
# dtype: int64

# %%
test = pd.read_csv('Group2_testing_data.csv')

# %%
test['Offer'] = test['Offer'].fillna('None')

# Verify the changes
print(test['Offer'].value_counts())
# Out:
# Offer
# None       883
# Offer B    200
# Offer E    166
# Offer D    141
# Offer A    103
# Offer C     98
# Name: count, dtype: int64

# %%
test.to_csv("Group2_testing_data.csv", index=False)

# %%
Y
# Out:
# 0        Stayed
# 1        Stayed
# 2        Stayed
# 3        Stayed
# 4        Stayed
#          ...
# 4765     Joined
# 4766     Stayed
# 4767    Churned
# 4768     Stayed
# 4769    Churned
# Name: Customer Status, Length: 4770, dtype: object

# %%
Y.replace({'Stayed': 0, 'Joined': 0, 'Churned': 1}, inplace=True)

# %%
Y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 4765    0
# 4766    0
# 4767    1
# 4768    0
# 4769    1
# Name: Customer Status, Length: 4770, dtype: int64

# %%
test
# Out:
#      Customer ID  Gender  Age Married  Number of Dependents  \
# 0     6127-ISGTU  Female   34     Yes                     0
# 1     6689-VRRTK  Female   71      No                     0
# 2     5843-TTHGI  Female   30      No                     0
# 3     4056-QHXHZ  Female   49     Yes                     2
# 4     9619-GSATL  Female   38      No                     0
# ...          ...     ...  ...     ...                   ...
# 1586  1705-GUHPV  Female   64      No                     0
# 1587  5233-AOZUF  Female   62     Yes                     0
# 1588  8194-PEEBY  Female   38     Yes                     3
# 1589  3191-CSNMG  Female   57     Yes                     1
# 1590  6992-TKNYO    Male   34     Yes                     0
#
#       Number of Referrals  Tenure in Months    Offer  \
# 0                       1                16     None
# 1                       0                44     None
# 2                       0                18     None
# ...

# %%
test.replace({'Stayed': 0, 'Joined': 0, 'Churned': 1}, inplace=True)

# %%
test
# Out:
#      Customer ID  Gender  Age Married  Number of Dependents  \
# 0     6127-ISGTU  Female   34     Yes                     0
# 1     6689-VRRTK  Female   71      No                     0
# 2     5843-TTHGI  Female   30      No                     0
# 3     4056-QHXHZ  Female   49     Yes                     2
# 4     9619-GSATL  Female   38      No                     0
# ...          ...     ...  ...     ...                   ...
# 1586  1705-GUHPV  Female   64      No                     0
# 1587  5233-AOZUF  Female   62     Yes                     0
# 1588  8194-PEEBY  Female   38     Yes                     3
# 1589  3191-CSNMG  Female   57     Yes                     1
# 1590  6992-TKNYO    Male   34     Yes                     0
#
#       Number of Referrals  Tenure in Months    Offer  \
# 0                       1                16     None
# 1                       0                44     None
# 2                       0                18     None
# ...

# %%
x.dtypes
# Out:
# Customer ID                           object
# Gender                                object
# Age                                    int64
# Married                               object
# Number of Dependents                   int64
# Number of Referrals                    int64
# Tenure in Months                       int64
# Offer                                 object
# Avg Monthly Long Distance Charges    float64
# Contract                              object
# Monthly Charge                       float64
# dtype: object

# %%
test.to_csv("Group2_testing_data.csv", index=False)

# %%
#feature selection

# %%
plt.figure(figsize=(8, 6))
sns.histplot(x['Age'], bins=20, kde=True)
plt.title("Distribution of Age")
plt.show()
# Out:
# /Users/kikanwaohanugo/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/kikanwaohanugo/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
print(x.columns)
# Out:
# Index(['Customer ID', 'Gender', 'Age', 'Married', 'Number of Dependents',
#        'Number of Referrals', 'Tenure in Months', 'Offer',
#        'Avg Monthly Long Distance Charges', 'Contract', 'Monthly Charge'],
#       dtype='object')

# %%
Y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 4765    0
# 4766    0
# 4767    1
# 4768    0
# 4769    1
# Name: Customer Status, Length: 4770, dtype: int64

# %%
Y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 4765    0
# 4766    0
# 4767    1
# 4768    0
# 4769    1
# Name: Customer Status, Length: 4770, dtype: int64

# %%
x
# Out:
#      Customer ID  Gender  Age Married  Number of Dependents  \
# 0     1135-HIORI  Female   48     Yes                     3
# 1     5847-MXBEO    Male   42      No                     0
# 2     2931-XIQBR  Female   41     Yes                     3
# 3     4468-YDOVK    Male   57      No                     2
# 4     8441-SHIPE  Female   53      No                     0
# ...          ...     ...  ...     ...                   ...
# 4765  4090-KPJIP  Female   42      No                     0
# 4766  2171-UDMFD    Male   22     Yes                     3
# 4767  6047-YHPVI    Male   56      No                     3
# 4768  1666-JXLKU  Female   64      No                     0
# 4769  9269-CQOOL    Male   58      No                     0
#
#       Number of Referrals  Tenure in Months    Offer  \
# 0                       3                64  Offer B
# 1                       0                22  Offer D
# 2                       7                50     None
# ...

# %%
from scipy.stats import pearsonr

# Example DataFrame with possible non-numeric values
data = {'Age': [42, 22, 56, 64, 58], 
        'Customer Status': [0, 0, 1, 0, 1]}

df = pd.DataFrame(data)

# Convert 'Age' column to numeric, replacing non-numeric values with NaN
df['Age'] = pd.to_numeric(df['Age'], errors='coerce')

# Drop rows with NaN values
df = df.dropna()

# Calculate Pearson correlation
correlation, p_value = pearsonr(df['Age'], df['Customer Status'])

# Print the correlation coefficient
print("Pearson Correlation Coefficient:", correlation)
# Out:
# Pearson Correlation Coefficient: 0.46684007016104345

# %%
x
# Out:
#      Customer ID  Gender  Age Married  Number of Dependents  \
# 0     1135-HIORI  Female   48     Yes                     3
# 1     5847-MXBEO    Male   42      No                     0
# 2     2931-XIQBR  Female   41     Yes                     3
# 3     4468-YDOVK    Male   57      No                     2
# 4     8441-SHIPE  Female   53      No                     0
# ...          ...     ...  ...     ...                   ...
# 4765  4090-KPJIP  Female   42      No                     0
# 4766  2171-UDMFD    Male   22     Yes                     3
# 4767  6047-YHPVI    Male   56      No                     3
# 4768  1666-JXLKU  Female   64      No                     0
# 4769  9269-CQOOL    Male   58      No                     0
#
#       Number of Referrals  Tenure in Months    Offer  \
# 0                       3                64  Offer B
# 1                       0                22  Offer D
# 2                       7                50     None
# ...

# %%
x['Married'] = (x['Married'] == 'Yes').astype(int)

# %%
x
# Out:
#      Customer ID  Gender  Age  Married  Number of Dependents  \
# 0     1135-HIORI  Female   48        1                     3
# 1     5847-MXBEO    Male   42        0                     0
# 2     2931-XIQBR  Female   41        1                     3
# 3     4468-YDOVK    Male   57        0                     2
# 4     8441-SHIPE  Female   53        0                     0
# ...          ...     ...  ...      ...                   ...
# 4765  4090-KPJIP  Female   42        0                     0
# 4766  2171-UDMFD    Male   22        1                     3
# 4767  6047-YHPVI    Male   56        0                     3
# 4768  1666-JXLKU  Female   64        0                     0
# 4769  9269-CQOOL    Male   58        0                     0
#
#       Number of Referrals  Tenure in Months    Offer  \
# 0                       3                64  Offer B
# 1                       0                22  Offer D
# 2                       7                50     None
# ...

# %%
x['Gender'] = (x['Gender'] == 'Female').astype(int)

# %%
x
# Out:
#      Customer ID  Gender  Age  Married  Number of Dependents  \
# 0     1135-HIORI       1   48        1                     3
# 1     5847-MXBEO       0   42        0                     0
# 2     2931-XIQBR       1   41        1                     3
# 3     4468-YDOVK       0   57        0                     2
# 4     8441-SHIPE       1   53        0                     0
# ...          ...     ...  ...      ...                   ...
# 4765  4090-KPJIP       1   42        0                     0
# 4766  2171-UDMFD       0   22        1                     3
# 4767  6047-YHPVI       0   56        0                     3
# 4768  1666-JXLKU       1   64        0                     0
# 4769  9269-CQOOL       0   58        0                     0
#
#       Number of Referrals  Tenure in Months    Offer  \
# 0                       3                64  Offer B
# 1                       0                22  Offer D
# 2                       7                50     None
# ...

# %%
# Example DataFrame with possible non-numeric values
data = {'Gender': [1, 0, 0, 1, 0], 
        'Customer Status': [0, 0, 1, 0, 1]}

df = pd.DataFrame(data)

# Convert 'Age' column to numeric, replacing non-numeric values with NaN
df['Gender'] = pd.to_numeric(df['Gender'], errors='coerce')

# Drop rows with NaN values
df = df.dropna()

# Calculate Pearson correlation
correlation, p_value = pearsonr(df['Gender'], df['Customer Status'])

# Print the correlation coefficient
print("Pearson Correlation Coefficient:", correlation)
# Out:
# Pearson Correlation Coefficient: -0.6666666666666669

# %%
# Example DataFrame with possible non-numeric values
data = {'Married': [0, 1, 0, 0, 0], 
        'Customer Status': [0, 0, 1, 0, 1]}

df = pd.DataFrame(data)

# Convert 'Age' column to numeric, replacing non-numeric values with NaN
df['Married'] = pd.to_numeric(df['Married'], errors='coerce')

# Drop rows with NaN values
df = df.dropna()

# Calculate Pearson correlation
correlation, p_value = pearsonr(df['Gender'], df['Customer Status'])

# Print the correlation coefficient
print("Pearson Correlation Coefficient:", correlation)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Gender'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[77], line 14
#      11 df = df.dropna()
#      13 # Calculate Pearson correlation
# ...

# %%
# Example DataFrame with possible non-numeric values
data = {'Number of Dependents': [0, 0, 5, 0, 0], 
        'Customer Status': [0, 0, 1, 0, 1]}

df = pd.DataFrame(data)

# Convert 'Age' column to numeric, replacing non-numeric values with NaN
df['Number of Dependents'] = pd.to_numeric(df['Number of Dependents'], errors='coerce')

# Drop rows with NaN values
df = df.dropna()

# Calculate Pearson correlation
correlation, p_value = pearsonr(df['Number of Dependents'], df['Customer Status'])

# Print the correlation coefficient
print("Pearson Correlation Coefficient:", correlation)
# Out:
# Pearson Correlation Coefficient: 0.6123724356957946

# %%
x[['Gender', 'Age', 'Married', 'Number of Dependents']].corr()
# Out:
#                         Gender       Age   Married  Number of Dependents
# Gender                1.000000 -0.008859 -0.009970             -0.008318
# Age                  -0.008859  1.000000 -0.009026             -0.117771
# Married              -0.009970 -0.009026  1.000000              0.322097
# Number of Dependents -0.008318 -0.117771  0.322097              1.000000

# %%
print("Columns in DataFrame:", df.columns)
# Out:
# Columns in DataFrame: Index(['Number of Dependents', 'Customer Status'], dtype='object')

# %%
print("Data types:")
# Out:
# Data types:

# %%
print("Unique values in 'Customer Status':", Y.unique())
# Out:
# Unique values in 'Customer Status': [0 1]

# %%
print("Data type of 'Customer Status':", Y.dtype)
# Out:
# Data type of 'Customer Status': int64

# %%
Y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Customer Status, dtype: int64

# %%
# Assuming 'Age' is the correct column name in your 'x' DataFrame
# and 'Customer Status' is your target variable in the 'Y' DataFrame
# Replace 'Age' with the actual column name in your dataset
column_name = 'Age'

# Combine 'Age' and 'Customer Status' horizontally
combined_data = pd.concat([x[column_name], Y], axis=1)

# Drop rows with NaN values
combined_data = combined_data.dropna()

# Calculate Pearson correlation
correlation, p_value = pearsonr(combined_data[column_name], combined_data['Customer Status'])

# Print the correlation coefficient
print(f"Pearson Correlation Coefficient between '{column_name}' and 'Customer Status': {correlation}")
# Out:
# Pearson Correlation Coefficient between 'Age' and 'Customer Status': 0.09808255113023097

# %%
# Assuming 'Age' is the correct column name in your 'x' DataFrame
# and 'Customer Status' is your target variable in the 'Y' DataFrame
# Replace 'Age' with the actual column name in your dataset
column_name = 'Married'

# Combine 'Age' and 'Customer Status' horizontally
combined_data = pd.concat([x[column_name], Y], axis=1)

# Drop rows with NaN values
combined_data = combined_data.dropna()

# Calculate Pearson correlation
correlation, p_value = pearsonr(combined_data[column_name], combined_data['Customer Status'])

# Print the correlation coefficient
print(f"Pearson Correlation Coefficient between '{column_name}' and 'Customer Status': {correlation}")
# Out:
# Pearson Correlation Coefficient between 'Married' and 'Customer Status': -0.15426650835385264

# %%
column_name = 'Gender'

combined_data = pd.concat([x[column_name], Y], axis=1)

combined_data = combined_data.dropna()

correlation, p_value = pearsonr(combined_data[column_name], combined_data['Customer Status'])

print(f"Pearson Correlation Coefficient between '{column_name}' and 'Customer Status': {correlation}")
# Out:
# Pearson Correlation Coefficient between 'Gender' and 'Customer Status': 0.011761305799749327

# %%
column_name = 'Number of Dependents'

combined_data = pd.concat([x[column_name], Y], axis=1)


combined_data = combined_data.dropna()

correlation, p_value = pearsonr(combined_data[column_name], combined_data['Customer Status'])

print(f"Pearson Correlation Coefficient between '{column_name}' and 'Customer Status': {correlation}")
# Out:
# Pearson Correlation Coefficient between 'Number of Dependents' and 'Customer Status': -0.22849132892802235

# %%
column_name = 'Number of Referrals'

combined_data = pd.concat([x[column_name], Y], axis=1)

combined_data = combined_data.dropna()

correlation, p_value = pearsonr(combined_data[column_name], combined_data['Customer Status'])

print(f"Pearson Correlation Coefficient between '{column_name}' and 'Customer Status': {correlation}")
# Out:
# Pearson Correlation Coefficient between 'Number of Referrals' and 'Customer Status': -0.2865687537064581

# %%
column_name = 'Tenure in Months'
combined_data = pd.concat([x[column_name], Y], axis=1)

combined_data = combined_data.dropna()

correlation, p_value = pearsonr(combined_data[column_name], combined_data['Customer Status'])

print(f"Pearson Correlation Coefficient between '{column_name}' and 'Customer Status': {correlation}")
# Out:
# Pearson Correlation Coefficient between 'Tenure in Months' and 'Customer Status': -0.3535699903391766

# %%
column_name = 'Avg Monthly Long Distance Charges'
combined_data = pd.concat([x[column_name], Y], axis=1)

combined_data = combined_data.dropna()

correlation, p_value = pearsonr(combined_data[column_name], combined_data['Customer Status'])

print(f"Pearson Correlation Coefficient between '{column_name}' and 'Customer Status': {correlation}")
# Out:
# Pearson Correlation Coefficient between 'Avg Monthly Long Distance Charges' and 'Customer Status': 0.0018421374386787144

# %%
column_name = 'Monthly Charge'
combined_data = pd.concat([x[column_name], Y], axis=1)

combined_data = combined_data.dropna()

correlation, p_value = pearsonr(combined_data[column_name], combined_data['Customer Status'])

print(f"Pearson Correlation Coefficient between '{column_name}' and 'Customer Status': {correlation}")
# Out:
# Pearson Correlation Coefficient between 'Monthly Charge' and 'Customer Status': 0.21055247233674257

# %%
import matplotlib.pyplot as plt
import seaborn as sns


df_vis = pd.concat([x['Tenure in Months'], Y], axis=1)

plt.figure(figsize=(10, 6))
sns.kdeplot(df_vis[df_vis['Customer Status'] == 0]['Tenure in Months'], label='Not Churned', shade=True)
sns.kdeplot(df_vis[df_vis['Customer Status'] == 1]['Tenure in Months'], label='Churned', shade=True)
plt.title('Distribution of Tenure in Months by Customer Status')
plt.xlabel('Tenure in Months')
plt.ylabel('Density')
plt.legend()
plt.show()
# Out:
# /var/folders/3w/djc6b4fn7h93v51r1lm18bq80000gn/T/ipykernel_90753/1711683417.py:8: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df_vis[df_vis['Customer Status'] == 0]['Tenure in Months'], label='Not Churned', shade=True)
# /Users/kikanwaohanugo/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/kikanwaohanugo/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns


df_vis = pd.concat([x['Tenure in Months'], Y], axis=1)

plt.figure(figsize=(10, 6))
sns.scatterplot(x='Tenure in Months', y='Customer Status', data=df_vis, alpha=0.5)
plt.title('Scatter Plot of Tenure in Months vs Customer Status')
plt.xlabel('Tenure in Months')
plt.ylabel('Customer Status')
plt.show()
# Out:
# /Users/kikanwaohanugo/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/kikanwaohanugo/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.scatterplot(x=x['Tenure in Months'], y=Y, hue=Y, palette={0: 'blue', 1: 'red'})
plt.title('Scatter Plot of Tenure in Months by Customer Status')
plt.xlabel('Tenure in Months')
plt.ylabel('Customer Status')
plt.legend(title='Churn', labels=['Not Churned', 'Churned'])
plt.show()
# Out:
# /Users/kikanwaohanugo/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/kikanwaohanugo/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/kikanwaohanugo/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
# Import necessary libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

rf_model = RandomForestClassifier()

rf_model.fit(x[['Tenure in Months']], Y)
# Out:
# /Users/kikanwaohanugo/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# /Users/kikanwaohanugo/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# /Users/kikanwaohanugo/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# ...

# %%
import pandas as pd
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Assuming you have already prepared the testing data (e.g., encoding categorical variables)
# Remove the target variable from the testing dataset
test_data_no_target1 = test.drop('Customer Status', axis=1)

# Make predictions on the test data
rf_predictions = rf_model.predict(test_data_no_target1[['Tenure in Months']])

# Evaluate the model's performance
accuracy = accuracy_score(test['Customer Status'], rf_predictions)
conf_matrix = confusion_matrix(test['Customer Status'], rf_predictions)
class_report = classification_report(test['Customer Status'], rf_predictions)

# Print the results
print(f"Accuracy: {accuracy}")
print(f"Confusion Matrix:\n{conf_matrix}")
print(f"Classification Report:\n{class_report}")
# Out:
# Accuracy: 0.7448145820238844
# Confusion Matrix:
# [[1088   78]
#  [ 328   97]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.93      0.84      1166
#            1       0.55      0.23      0.32       425
#
#     accuracy                           0.74      1591
#    macro avg       0.66      0.58      0.58      1591
# weighted avg       0.71      0.74      0.70      1591
# /Users/kikanwaohanugo/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# /Users/kikanwaohanugo/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# ...
